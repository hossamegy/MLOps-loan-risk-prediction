# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df1= pd.read_csv('/content/loan_risk_prediction_dataset.csv')

# %%
df1.head()
# Out:
#                                                 text  protein  carbs    fat  \
# 0                                       134g almonds    28.21  29.55  65.82
# 1  140g beans cooked, 198g banana, 135g chicken b...    56.45  77.71   6.14
# 2                   164g cheese cheddar, 186g tomato    42.75   9.39  54.59
# 3                     177g chicken breast, 94g apple    55.00  13.22   6.54
# 4                   151g lentils cooked, 170g banana    15.47  69.26   1.11
#
#    fiber  sugar   sodium  calories health_class  \
# 0  16.79   2.73     1.34    823.42    Unhealthy
# 1  13.53  20.09   104.31    591.90     Balanced
# 2   2.23   9.63  1029.55    699.87    Unhealthy
# 3   2.27   7.25   131.57    331.74     Balanced
# 4  16.50   7.46     4.72    348.91     Balanced
#
#                                     nutrition_labels
# 0  High Fat|High Fiber|High Protein|Low Sodium|Lo...
# 1  High Carb|High Fiber|High Protein|High Sugar|L...
# 2         High Fat|High Protein|High Sodium|Low Carb
# ...

# %%
df2.head()
# Out:
#         Food_Item  calories  protein  carbs   fat  fiber  sugar  sodium  \
# 0  chicken breast     144.4     28.0    0.0   3.6    0.0    0.0    74.0
# 1     beef (lean)     239.0     26.0    0.0  15.0    0.0    0.0    72.0
# 2          salmon     205.0     22.0    0.0  13.0    0.0    0.0    60.0
# 3            eggs     138.7     12.6    0.7   9.5    0.0    0.4   124.0
# 4            tofu      82.8      8.0    1.9   4.8    0.3    0.7     7.0
#
#    Default_Weight                                           Aliases  \
# 0             100              chicken, poultry, breast, white meat
# 1             100                  meat, beef, steak, red meat, cow
# 2             100                  fish, salmon, seafood, pink fish
# 3             100  egg, eggs, boiled egg, fried egg, protein source
# 4             100          tofu, bean curd, soy protein, vegan meat
#
#                                    nutrition_profile
# 0  High Protein|Low Carb|Low Fat|Low Fiber|Low So...
# ...
